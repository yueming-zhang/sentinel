# %%
import matplotlib.pyplot as plt
import rasterio

def show_img(p):
    with rasterio.open(p) as src:
        image_data = src.read()
    plt.imshow(image_data[10])

# %%
o1 = '/home/ming/BP/sentinel/sentinel_preprocessed/2be6703e4380caaba3b764c18729e1cd.tiff'
p1 = '/home/ming/BP/sentinel/sentinel_preprocessed/EPSG3857/2be6703e4380caaba3b764c18729e1cd.tiff'
p2 = '/home/ming/BP/sentinel/sentinel_preprocessed/3a1f963e88f3f33fa382e8e2905ca1eb.tiff'

stitched = '/home/ming/BP/sentinel/sentinel_preprocessed/EPSG3857/stitched.tiff'
show_img(o1)

# %%
show_img(p1)
